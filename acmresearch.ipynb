# %% [markdown]
# # Import Statements

# %%
import pandas as pd #For files
import numpy as np
import matplotlib.pyplot as plt #Plotting future predictions
import seaborn as sns
plt.style.use('dark_background') #Dark theme is OG :P

# %%
#Read the CSV Data
df = pd.read_csv('../input/asdsgdfgsdfg/mushrooms.csv') 
#Display the CSV in console
df.head()

# %%
#Contains numeric column descriptions
df.describe()

# %%
#See the shape of the data set in columns and rows
df.shape

# %%
#Tells me how many columns are null and non-null
df.info()

# %%
#Drop the columns which are always null or always non-null because they are insignificant for the model training
df = df.drop(["bruises","gill-attachment","stalk-surface-above-ring","stalk-color-above-ring","stalk-color-below-ring","veil-type","veil-color","ring-number","ring-type"             ], axis =1)
df.head()

# %%
#Drop the rows of the above columns
df = df.dropna(axis = 0)
df.shape

# %%
#See the current columns in the data frame.
df.columns

# %%
#String data cannot be transfered into a model,so we have to us Label Encoding to transfer the Strings into Integers for each column.
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['class'] = le.fit_transform(df['class'])

df['cap-shape'] = le.fit_transform(df['cap-shape'])
df['cap-surface'] = le.fit_transform(df['cap-surface'])
df['odor'] = le.fit_transform(df['odor'])
df['gill-spacing'] = le.fit_transform(df['gill-spacing'])
df['gill-size'] = le.fit_transform(df['gill-size'])
df['gill-color'] = le.fit_transform(df['gill-color'])
df['stalk-shape'] = le.fit_transform(df['stalk-shape'])
df['stalk-root'] = le.fit_transform(df['stalk-root'])
df['stalk-surface-below-ring'] = le.fit_transform(df['stalk-surface-below-ring'])
df['spore-print-color'] = le.fit_transform(df['spore-print-color'])
df['population'] = le.fit_transform(df['population'])
df['habitat'] = le.fit_transform(df['habitat'])

# %%
#We now see that all the string data is numeric data.
df.head

# %%
x = df.drop(['class'], axis = 1)
y = df['gill-size']

# %%
#View the file again
x.head()

# %% [markdown]
# # Heatmap

# %%
#Draw a heatmap to see the correlation between each and every column.
plt.figure(figsize = (8,8)) 
#We can see that the following have a strong correlation.
sns.heatmap(df.corr()) 
#Class and Gill Size, Class and population, and gill size and spore-print-color.

# %%
#Split the dataset into train and test data.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2) #Test size is 20%.

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression #An Attempt and logistic regression. The console was having problems with the training set.
lr = LogisticRegression()
lr.fit(x_train ,y_train)
predictions = lr.predict(x_test)
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
print(accuracy_score(y_test, predictions))
